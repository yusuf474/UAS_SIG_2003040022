# %% [markdown]
# Nama : Mohamad Yusuf Alim Rifai
# NIM : 2003040022
#
# Link tutorial : https://www.youtube.com/watch?v=JoQhEKh7u0c&t=8s&ab_channel=GeospatialProgramming
#
#
# Data : https://tanahair.indonesia.go.id/portal-web/
#
# konversi ke GeoJSON : https://mapshaper.org/

# %%
# mengimport modul 'warnings'
import warnings
warnings.filterwarnings('ignore')

# %%
# mengimpor pustaka Geopandas ke dalam program Python
import geopandas as gpd

# %%
# membaca file GeoJSON yang disebut "RBI25K_ADMINISTRASI_LN.json"
gdf = gpd.read_file("RBI25K_ADMINISTRASI_LN.json")

# menampilkan lima baris pertama dari GeoDataFrame
gdf.head()
# Out:
#                     NAMOBJ       FCODE                         REMARK  \
# 0    Pangandaran - Cilacap  BA02070040                    Garis Bantu
# 1    Pangandaran - Cilacap  BA02060040  Data Digital Kemendagri (Dwg)
# 2  Banjarnegara - Banyumas  BA02060040    Sesuai Dengan Peta Lampiran
# 3        Banyumas - Brebes  BA02060040        Data Digital Kemendagri
# 4     Kota Banjar - Ciamis  BA02060040   Berbeda Dengan Peta Lampiran
#
#                                  METADATA SRS_ID ADMIN1 ADMIN2  KARKTR  \
# 0  TASWIL2500020210531_DATA_BATAS_KABKOTA         32.07  33.01     999
# 1  TASWIL2500020210531_DATA_BATAS_KABKOTA         32.07  33.01     999
# 2  TASWIL2500020210531_DATA_BATAS_KABKOTA         33.04  33.02     999
# 3  TASWIL2500020210531_DATA_BATAS_KABKOTA         33.02  33.29     999
# 4  TASWIL2500020210531_DATA_BATAS_KABKOTA         32.79  32.07     999
#
#    KLBADM  PJGBTS  ...  WADKC1  WADKC2        WAKBK1    WAKBK2 WAKLD1 WAKLD2  \
# ...

# %%
# memfilter kolom yang akan di panggil
# Setelah pemilihan kolom, fungsi fillna(0) digunakan untuk menggantikan nilai-nilai yang kosong (NaN)
# dalam GeoDataFrame dengan nilai 0.
gdf = gdf[['NAMOBJ', 'FCODE', 'REMARK', 'METADATA', 'geometry']].fillna(0)

# %%
# menginstal tiga pustaka Python, yaitu Folium, Matplotlib, dan Mapclassify,
# menggunakan perintah pip langsung dari dalam sebuah lingkungan notebook atau console.
# !pip install folium matplotlib mapclassify

# %%
# !pip install folium

# %%
# !pip install folium
# !pip install geopandas
# !pip install shapely
# !pip install fiona
# !pip install pyogrio
# !pip install rtree
# !pip install pyproj
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.0/22.0 MB 58.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 488.6/488.6 kB 5.3 MB/s eta 0:00:00
# ...

# %%
# mengimpor pustaka Folium ke dalam program Python
import folium

# Membuat objek peta interaktif
m = gdf.explore(column="METADATA", name="MetaData")

# Menambahkan kontrol lapisan ke peta
folium.LayerControl().add_to(m)

# Menampilkan peta interaktif
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
